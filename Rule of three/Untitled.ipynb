# %%
x= str(input("Please introduce measure in cm"))
print(x)
w=x*755
print(w)
Z=str(a)%int(11)
print("Z")
# Out:
# Please introduce measure in cm1.9
# 1.9
# ...

# %%
c=float(input("Input cm"))
c=round(c,2)
a=c*755
a=round(a,2)
print(a)
b=round(a,2)//round(11,2)
b=round(b,2)
print(b)
f"{b:.2f}"
# Out:
# Input cm0.4
# 302.0
# 27.0
# '27.00'
